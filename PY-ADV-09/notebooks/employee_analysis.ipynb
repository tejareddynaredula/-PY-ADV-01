# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/employees.csv")
df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun   NaN         IT   50000
# 4  Rahul  25.0         HR   45000
# 5  Sneha  30.0        NaN   65000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        6 non-null      str
#  1   age         5 non-null      float64
#  2   department  5 non-null      str
#  3   salary      6 non-null      int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 324.0 bytes

# %%
df.isnull().sum()
# Out:
# name          0
# age           1
# department    1
# salary        0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())
df["department"] = df["department"].fillna("Unknown")

df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Rahul  25.0         HR   45000
# 5  Sneha  30.0    Unknown   65000

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Sneha  30.0    Unknown   65000

# %%
df.groupby("department")["name"].count()
# Out:
# department
# Finance    1
# HR         1
# IT         2
# Unknown    1
# Name: name, dtype: int64

# %%
df.groupby("department")["salary"].mean()
# Out:
# department
# Finance    60000.0
# HR         45000.0
# IT         52500.0
# Unknown    65000.0
# Name: salary, dtype: float64

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.5.2

# %%
arr = np.array([10, 20, 30, 40, 50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr.ndim
# Out:
# 1

# %%
arr + 5
# Out:
# array([15, 25, 35, 45, 55])

# %%
arr[0]
# Out:
# np.int64(10)

# %%
arr + 5
# Out:
# array([15, 25, 35, 45, 55])

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
data = {
    "Name": ["Teja", "Rahul", "Priya"],
    "Age": [22, 25, 28]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0   Teja   22
# 1  Rahul   25
# 2  Priya   28

# %%
df = pd.read_csv("../data/employees.csv")
df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun   NaN         IT   50000
# 4  Rahul  25.0         HR   45000
# 5  Sneha  30.0        NaN   65000

# %%
high_salary = df[df["salary"] > 50000]
high_salary
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 2  Priya  28.0    Finance   60000
# 5  Sneha  30.0        NaN   65000

# %%
df.sort_values("salary", ascending=False)
# Out:
#     name   age department  salary
# 5  Sneha  30.0        NaN   65000
# 2  Priya  28.0    Finance   60000
# 0   Teja  22.0         IT   55000
# 3  Arjun   NaN         IT   50000
# 1  Rahul  25.0         HR   45000
# 4  Rahul  25.0         HR   45000

# %%
df.isnull().sum()
# Out:
# name          0
# age           1
# department    1
# salary        0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())
df["department"] = df["department"].fillna("Unknown")
df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Rahul  25.0         HR   45000
# 5  Sneha  30.0    Unknown   65000

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Sneha  30.0    Unknown   65000

# %%
df.groupby("department")["name"].count()
# Out:
# department
# Finance    1
# HR         1
# IT         2
# Unknown    1
# Name: name, dtype: int64

# %%
df.groupby("department")["salary"].agg(["count", "mean", "min", "max"])
# Out:
#             count     mean    min    max
# department
# Finance         1  60000.0  60000  60000
# HR              1  45000.0  45000  45000
# IT              2  52500.0  50000  55000
# Unknown         1  65000.0  65000  65000

# %%
managers = pd.DataFrame({
    "department": ["IT", "HR", "Finance", "Unknown"],
    "manager": ["Ravi", "Anil", "Kiran", "Unassigned"]
})

df.merge(managers, on="department", how="left")
# Out:
#     name   age department  salary     manager
# 0   Teja  22.0         IT   55000        Ravi
# 1  Rahul  25.0         HR   45000        Anil
# 2  Priya  28.0    Finance   60000       Kiran
# 3  Arjun  26.0         IT   50000        Ravi
# 4  Sneha  30.0    Unknown   65000  Unassigned

# %%
df.describe()
# Out:
#             age       salary
# count   5.00000      5.00000
# mean   26.20000  55000.00000
# std     3.03315   7905.69415
# min    22.00000  45000.00000
# 25%    25.00000  50000.00000
# 50%    26.00000  55000.00000
# 75%    28.00000  60000.00000
# max    30.00000  65000.00000

# %%
df = pd.read_csv("../data/employees.csv")

df["age"] = df["age"].fillna(df["age"].mean())
df["department"] = df["department"].fillna("Unknown")

df = df.drop_duplicates().reset_index(drop=True)

df.to_csv("../data/employees_clean.csv", index=False)

df
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Sneha  30.0    Unknown   65000

# %%
pd.read_csv("../data/employees_clean.csv")
# Out:
#     name   age department  salary
# 0   Teja  22.0         IT   55000
# 1  Rahul  25.0         HR   45000
# 2  Priya  28.0    Finance   60000
# 3  Arjun  26.0         IT   50000
# 4  Sneha  30.0    Unknown   65000
